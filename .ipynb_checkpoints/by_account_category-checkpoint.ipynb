# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

data = "../data/"#data = "/IRA je sais pas quoi

# %%
df = pd.read_csv(data + "IRAhandle_tweets_1.csv")
for i in range(2, 10):
    df = df.append(pd.read_csv(data + "IRAhandle_tweets_{}.csv".format(i)), ignore_index=True)
    
df = df.dropna()

# %%
hashtags = []
for t in df.content.values:
    m = re.search("#.* ", t)
    if m is not None:
        for hashtag in m.group(0).split(" "):
            if hashtag and hashtag[0] == "#":
                hashtags.append(hashtag)

# %%
import collections

a = collections.Counter(hashtags)

df["publish_date"] =pd.to_datetime(df["publish_date"], format='%m/%d/%Y %H:%M')
#print(df["publish_date"])
df["harvested_date"] =pd.to_datetime(df["harvested_date"], format='%m/%d/%Y %H:%M')

df
# Out:
#          external_author_id           author  \
# 2              9.060000e+17           10_GOP
# 4              9.060000e+17           10_GOP
# 6              9.060000e+17           10_GOP
# 17             9.060000e+17           10_GOP
# 20             9.060000e+17           10_GOP
# 23             9.060000e+17           10_GOP
# 25             9.060000e+17           10_GOP
# 28             9.060000e+17           10_GOP
# 30             9.060000e+17           10_GOP
# 33             9.060000e+17           10_GOP
# 34             9.060000e+17           10_GOP
# 35             9.060000e+17           10_GOP
# 40             9.060000e+17           10_GOP
# 42             9.060000e+17           10_GOP
# 43             9.060000e+17           10_GOP
# 45             9.060000e+17           10_GOP
# 46             9.060000e+17           10_GOP
# 47             9.060000e+17           10_GOP
# 49             9.060000e+17           10_GOP
# 60             9.060000e+17           10_GOP
# ...

# %%
a.most_common(300)
# Out:
# [('#MAGA', 6664),
#  ('#tcot', 5759),
#  ('#NowPlaying', 3333),
#  ('#Trump', 3218),
#  ('#BlackLivesMatter', 3106),
#  ('#PJNET', 2697),
#  ('#новости', 2604),
#  ('#news', 2240),
#  ('#2A', 2080),
#  ('#ToDoListBeforeChristmas', 1995),
#  ('#p2', 1979),
#  ('#ISIS', 1941),
#  ('#IHatePokemonGoBecause', 1934),
#  ('#IGetDepressedWhen', 1898),
#  ('#WakeUpAmerica', 1795),
#  ('#IStartCryingWhen', 1781),
#  ('#local', 1779),
#  ('#NowPlaying:', 1777),
#  ('#DontTellAnyoneBut', 1762),
#  ('#ToAvoidWorkI', 1727),
#  ('#ThingsYouCantIgnore', 1605),
#  ('#TCOT', 1564),
#  ('#ccot', 1538),
#  ('#MyOlympicSportWouldBe', 1508),
#  ('#ToFeelBetterI', 1500),
#  ('#GiftIdeasForPoliticians', 1424),
#  ('#ChildrenThinkThat', 1388),
#  ('#2016In4Words', 1344),
#  ('#ItsRiskyTo', 1331),
#  ('#NeverHillary', 1297),
#  ('#WhenIWasYoung', 1285),
#  ('#ObamasWishList', 1282),
#  ('#INeedALawyerBecause', 1274),
#  ('#Chicago', 1255),
#  ('#hiphop', 1235),
#  ('#TrumpTrain', 1224),
# ...

# %%
def related(df, hashtag, category=None):
    dump = ["", "the", "-", "of", "is", "to", "a", "in", "for", "and", "The", "on", "you", "our", "not", "&", "with", \
           "We", "are", "I", "be", "with", "we", "your", "To", "will", "who", "In", "via", "that", "In", \
           "Is", "this", "it", "by", "THE", "their", "my", "1.", "2.", "all", "at", "Get", "get", "up", \
           "out", "new", "some", "about", "This", "have", "was", "as", "from", "they", "has", "his", "You"\
           "what", "he", "an", "but", "You", "what", "so", "if", "more", "do", "like", "just", "can", "how", \
           "If", "A", "or", "should", "For", "no", "Of", 'one', 'With', "It's", 'He', "I'm", 'want', 'And', 'They', 'when',\
           'It', 'My', 'would', 'US', '4', 'back', 'What', 'us', 'New', 'going', 'Great', 'over', 'time', "don't", 'after', \
            'know', 'than', 'think', 'need', 'take', 'On', "because", "me", "Who", '��','�']
    hashtags = []
    people = []
    words = []

    if category is not None:
        df = df[df.account_category == category]
        
    tweets = [x for x in df.content.values if hashtag in x]
    for tweet in tweets: 
        for word in tweet.split(" "):
            if word and word not in dump:
                if word[0] == "#":
                    hashtags.append(word)
                elif word[0] == "@":
                    people.append(word)
                else:
                    words.append(word)
    
    all_ = [collections.Counter(hashtags), collections.Counter(people), collections.Counter(words)]
    for counter in all_:
        print([a for (a, _) in counter.most_common(30)])
        print()
    return tuple(all_)

# %%
hashtags, people, words = related(df, "#GiftIdeasForPoliticians")
# Out:
# ['#GiftIdeasForPoliticians', '#InformTheElectors', '#ActualRealityNotVirtual', '#Trump', '#MAGA', '#SNL', '#BlackLivesMatter', '#payforwork', '#Aleppo', '#Patriots', '#GiftIdeasForPoliticians?', '#GameAlert', '#GiftIdeasForPoliticians:', '#GiftIdeasForPoliticians.', '#GiftIdeasForPoliticians,', '#SandyHook', '#Antarctica.', '#tcot', '#S8114', '#MerryChristmas']
#
# ['@nbcsnl', '@Walmart', '@BarackObama', '@realDonaldTrump', '@HillaryClinton', '@SenatorReid', '@ddale8', '@WorldOfHashtags', '@BernieSanders']
#
# ['something', 'them', '&amp;', 'Trump', 'real', 'Donald', 'copy', 'minimum', 'good', 'ticket', 'water', 'way', 'books', 'book', 'face', 'American', 'place', 'present', 'Free', 'An', 'Maybe', 'lie', 'year', 'hell', '"I\'m', 'into', 'Clinton', 'Hillary', 'look', 'free']

# %%
def histograms_bydate(df):
    d= df["publish_date"].groupby(df["publish_date"].dt.date).apply(pd.value_counts)
    return d
def histograms_by_account_type(df):
    d = df[["publish_date", "account_category"]].groupby([df["publish_date"].dt.date, df["account_category"]]).agg("count")
    return d

# %%
res=histograms_bydate(df)
res= res.groupby("publish_date").sum()
#res

# %%
ax =res.plot()
plt.show()

# %%
by_account= histograms_by_account_type(df)
by_account=by_account.drop("publish_date", axis=1)
by_account.columns = ["count"]
by_account
# Out:
#                                count
# publish_date account_category
# 2012-11-18   NonEnglish            1
# 2012-11-28   LeftTroll             1
# 2012-12-02   NonEnglish            1
# 2012-12-05   NonEnglish            1
# 2012-12-15   NonEnglish            1
# 2012-12-26   LeftTroll             1
# 2013-02-21   NonEnglish            2
# 2013-02-27   NonEnglish            1
# 2013-03-12   NonEnglish            1
# 2013-05-17   LeftTroll             1
# 2013-05-18   LeftTroll             2
# 2013-05-19   LeftTroll             1
# 2013-05-23   LeftTroll             1
# 2013-05-25   LeftTroll             1
# 2013-05-26   LeftTroll             1
# 2013-06-05   LeftTroll             1
# 2013-06-06   LeftTroll             1
# 2013-06-11   LeftTroll             1
# 2013-06-14   LeftTroll             2
# 2013-06-15   LeftTroll             1
# 2013-06-19   LeftTroll             2
# 2013-06-21   LeftTroll             1
# 2013-06-23   LeftTroll             1
# ...

# %%
by_account = by_account.reset_index().set_index("publish_date")
for cat in by_account.account_category.unique():
    tmp_df = by_account[by_account.account_category == cat]
    ax = tmp_df.plot(title=cat)

plt.show()

# %%
by_account.reset_index().set_index("publish_date")
# Out:
#              account_category  count
# publish_date
# 2012-11-18         NonEnglish      1
# 2012-11-28          LeftTroll      1
# 2012-12-02         NonEnglish      1
# 2012-12-05         NonEnglish      1
# 2012-12-15         NonEnglish      1
# 2012-12-26          LeftTroll      1
# 2013-02-21         NonEnglish      2
# 2013-02-27         NonEnglish      1
# 2013-03-12         NonEnglish      1
# 2013-05-17          LeftTroll      1
# 2013-05-18          LeftTroll      2
# 2013-05-19          LeftTroll      1
# 2013-05-23          LeftTroll      1
# 2013-05-25          LeftTroll      1
# 2013-05-26          LeftTroll      1
# 2013-06-05          LeftTroll      1
# 2013-06-06          LeftTroll      1
# 2013-06-11          LeftTroll      1
# 2013-06-14          LeftTroll      2
# 2013-06-15          LeftTroll      1
# 2013-06-19          LeftTroll      2
# 2013-06-21          LeftTroll      1
# 2013-06-23          LeftTroll      1
# 2013-06-25          LeftTroll      2
# ...
